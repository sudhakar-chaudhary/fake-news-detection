# %%
import pickle

# Load trained model
with open("/content/fake_news_model.pkl", "rb") as file:
    model = pickle.load(file)

# Load TF-IDF vectorizer
with open("/content/tfidf_vectorizer.pkl", "rb") as file:
    vectorizer = pickle.load(file)

print("Model and vectorizer loaded successfully!")
# Out:
# Model and vectorizer loaded successfully!

# %%
import re

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'http\S+|www\S+', '', text)
    text = re.sub(r'<.*?>', '', text)
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()

    return text

# %%
def predict_news(news):

    # Clean news
    cleaned_news = clean_text(news)

    # Convert to TF-IDF
    news_tfidf = vectorizer.transform([cleaned_news])

    # Predict
    prediction = model.predict(news_tfidf)[0]

    if prediction == 0:
        return "FAKE NEWS ❌"
    else:
        return "REAL NEWS ✅"

# %%
news = input("Enter news article: ")

result = predict_news(news)

print("\nPrediction:", result)
# Out:
# Enter news article: The Reserve Bank of India announced that it will maintain the current policy interest rate while continuing to monitor inflation and economic growth. The decision was announced after a meeting of the Monetary Policy Committee.
#
# Prediction: FAKE NEWS ❌
